# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from keras import optimizers, losses, activations, models
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, GlobalMaxPool1D, GlobalAveragePooling1D, \
    concatenate,SimpleRNN,LSTM,Embedding,GRU,Bidirectional
from sklearn.metrics import f1_score, accuracy_score
tf.random.set_seed(36)
df_train = pd.read_csv("mitbih_train.csv", header=None)
df_train = df_train.sample(frac=1)
df_test = pd.read_csv("mitbih_test.csv", header=None)

Y = np.array(df_train[187].values).astype(np.int8)
X = np.array(df_train[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]


def get_model():
    nclass = 5
    inp = Input(shape=(187, 1))
    img_1 = Convolution1D(16, kernel_size=5, activation=activations.relu, padding="valid")(inp)
    img_1 = Convolution1D(16, kernel_size=5, activation=activations.relu, padding="valid")(img_1)
    img_1 = MaxPool1D(pool_size=2)(img_1)
    img_1 = Dropout(rate=0.1)(img_1)
    img_1 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = MaxPool1D(pool_size=2)(img_1)
    img_1 = Dropout(rate=0.1)(img_1)
    img_1 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = MaxPool1D(pool_size=2)(img_1)
    img_1 = Dropout(rate=0.1)(img_1)
    img_1 = Convolution1D(256, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = Convolution1D(256, kernel_size=3, activation=activations.relu, padding="valid")(img_1)
    img_1 = GlobalMaxPool1D()(img_1)
    img_1 = Dropout(rate=0.2)(img_1)

    dense_1 = Dense(64, activation=activations.relu, name="dense_1")(img_1)
    dense_1 = Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.001)

    model.compile(optimizer=opt, loss=losses.sparse_categorical_crossentropy, metrics=['acc'])
    model.summary()
    return model

model = get_model()
file_path = "baseline_cnn_mitbih.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early

model.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

pred_test = model.predict(X_test)
pred_test = np.argmax(pred_test, axis=-1)

f1 = f1_score(Y_test, pred_test, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_test, pred_test)

print("Test accuracy score : %s "% acc)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 187, 1)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 183, 16)           96
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 179, 16)           1296
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 89, 16)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 89, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 87, 32)            1568
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 85, 32)            3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 42, 32)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 42, 32)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 40, 32)            3104
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 38, 32)            3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 19, 32)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 19, 32)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 17, 256)           24832
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 15, 256)           196864
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3_mitbih (Dense)       (None, 5)                 325
# =================================================================
# Total params: 254,901
# Trainable params: 254,901
# Non-trainable params: 0
# _________________________________________________________________
# Train on 78798 samples, validate on 8756 samples
# Epoch 1/1000
#  - 24s - loss: 0.3512 - acc: 0.8963 - val_loss: 0.1974 - val_acc: 0.9387
#
# Epoch 00001: val_acc improved from -inf to 0.93867, saving model to baseline_cnn_mitbih.h5
# Epoch 2/1000
#  - 27s - loss: 0.1956 - acc: 0.9471 - val_loss: 0.1405 - val_acc: 0.9616
#
# Epoch 00002: val_acc improved from 0.93867 to 0.96163, saving model to baseline_cnn_mitbih.h5
# Epoch 3/1000
#  - 26s - loss: 0.1580 - acc: 0.9578 - val_loss: 0.1366 - val_acc: 0.9651
#
# Epoch 00003: val_acc improved from 0.96163 to 0.96505, saving model to baseline_cnn_mitbih.h5
# Epoch 4/1000
#  - 26s - loss: 0.1361 - acc: 0.9637 - val_loss: 0.1130 - val_acc: 0.9710
#
# Epoch 00004: val_acc improved from 0.96505 to 0.97099, saving model to baseline_cnn_mitbih.h5
# Epoch 5/1000
#  - 27s - loss: 0.1227 - acc: 0.9670 - val_loss: 0.0982 - val_acc: 0.9741
#
# Epoch 00005: val_acc improved from 0.97099 to 0.97407, saving model to baseline_cnn_mitbih.h5
# Epoch 6/1000
#  - 25s - loss: 0.1129 - acc: 0.9695 - val_loss: 0.0920 - val_acc: 0.9766
#
# Epoch 00006: val_acc improved from 0.97407 to 0.97659, saving model to baseline_cnn_mitbih.h5
# Epoch 7/1000
#  - 26s - loss: 0.1051 - acc: 0.9710 - val_loss: 0.0817 - val_acc: 0.9769
#
# Epoch 00007: val_acc improved from 0.97659 to 0.97693, saving model to baseline_cnn_mitbih.h5
# Epoch 8/1000
#  - 27s - loss: 0.0982 - acc: 0.9736 - val_loss: 0.0861 - val_acc: 0.9745
#
# Epoch 00008: val_acc did not improve from 0.97693
# Epoch 9/1000
#  - 27s - loss: 0.0932 - acc: 0.9744 - val_loss: 0.0667 - val_acc: 0.9802
#
# Epoch 00009: val_acc improved from 0.97693 to 0.98024, saving model to baseline_cnn_mitbih.h5
# Epoch 10/1000
#  - 28s - loss: 0.0879 - acc: 0.9754 - val_loss: 0.0702 - val_acc: 0.9805
#
# Epoch 00010: val_acc improved from 0.98024 to 0.98047, saving model to baseline_cnn_mitbih.h5
# Epoch 11/1000
#  - 25s - loss: 0.0842 - acc: 0.9763 - val_loss: 0.0619 - val_acc: 0.9825
#
# Epoch 00011: val_acc improved from 0.98047 to 0.98253, saving model to baseline_cnn_mitbih.h5
# Epoch 12/1000
#  - 25s - loss: 0.0796 - acc: 0.9773 - val_loss: 0.0627 - val_acc: 0.9825
#
# Epoch 00012: val_acc did not improve from 0.98253
# Epoch 13/1000
#  - 28s - loss: 0.0756 - acc: 0.9784 - val_loss: 0.0568 - val_acc: 0.9841
#
# Epoch 00013: val_acc improved from 0.98253 to 0.98413, saving model to baseline_cnn_mitbih.h5
# Epoch 14/1000
#  - 27s - loss: 0.0747 - acc: 0.9789 - val_loss: 0.0602 - val_acc: 0.9815
#
# Epoch 00014: val_acc did not improve from 0.98413
# Epoch 15/1000
#  - 30s - loss: 0.0722 - acc: 0.9793 - val_loss: 0.0567 - val_acc: 0.9824
#
# Epoch 00015: val_acc did not improve from 0.98413
# Epoch 16/1000
#  - 25s - loss: 0.0703 - acc: 0.9800 - val_loss: 0.0566 - val_acc: 0.9829
#
# Epoch 00016: val_acc did not improve from 0.98413
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 17/1000
#  - 26s - loss: 0.0521 - acc: 0.9842 - val_loss: 0.0443 - val_acc: 0.9865
#
# Epoch 00017: val_acc improved from 0.98413 to 0.98652, saving model to baseline_cnn_mitbih.h5
# Epoch 18/1000
#  - 25s - loss: 0.0471 - acc: 0.9861 - val_loss: 0.0425 - val_acc: 0.9870
#
# Epoch 00018: val_acc improved from 0.98652 to 0.98698, saving model to baseline_cnn_mitbih.h5
# Epoch 19/1000
#  - 26s - loss: 0.0454 - acc: 0.9865 - val_loss: 0.0425 - val_acc: 0.9874
#
# Epoch 00019: val_acc improved from 0.98698 to 0.98744, saving model to baseline_cnn_mitbih.h5
# Epoch 20/1000
#  - 31s - loss: 0.0440 - acc: 0.9866 - val_loss: 0.0419 - val_acc: 0.9870
#
# Epoch 00020: val_acc did not improve from 0.98744
# Epoch 21/1000
#  - 26s - loss: 0.0422 - acc: 0.9872 - val_loss: 0.0410 - val_acc: 0.9879
#
# Epoch 00021: val_acc improved from 0.98744 to 0.98789, saving model to baseline_cnn_mitbih.h5
# Epoch 22/1000
#  - 30s - loss: 0.0404 - acc: 0.9879 - val_loss: 0.0405 - val_acc: 0.9877
#
# Epoch 00022: val_acc did not improve from 0.98789
# Epoch 23/1000
#  - 29s - loss: 0.0409 - acc: 0.9875 - val_loss: 0.0397 - val_acc: 0.9886
#
# Epoch 00023: val_acc improved from 0.98789 to 0.98858, saving model to baseline_cnn_mitbih.h5
# Epoch 24/1000
#  - 26s - loss: 0.0390 - acc: 0.9880 - val_loss: 0.0409 - val_acc: 0.9879
#
# Epoch 00024: val_acc did not improve from 0.98858
# Epoch 25/1000
#  - 27s - loss: 0.0378 - acc: 0.9882 - val_loss: 0.0401 - val_acc: 0.9882
#
# Epoch 00025: val_acc did not improve from 0.98858
# Epoch 26/1000
#  - 27s - loss: 0.0367 - acc: 0.9882 - val_loss: 0.0406 - val_acc: 0.9878
#
# Epoch 00026: val_acc did not improve from 0.98858
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch
- val_acc: 0.8284
#
# Epoch 00005: val_acc did not improve from 0.82836
# Epoch 6/1000
#  - 122s - loss: 0.6541 - acc: 0.8287 - val_loss: 0.6590 - val_acc: 0.8284
#
# Epoch 00006: val_acc did not improve from 0.82836
# Epoch 00006: early stopping
# Test f1 score : 0.18091031449640765
# Test accuracy score : 0.8257363375211989

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(
    X, Y, test_size=0.33, random_state=42)
def get_model():
    nclass = 5
    inp = Input(shape=(187, 1))
    
    img_1 = Dropout(rate=0.1)(inp)
    img_1 = SimpleRNN(64)(img_1)
    img_1 = Dropout(rate=0.1)(img_1)
    dense_1 = Dense(64, activation=activations.relu, name="dense_1")(img_1)
    dense_1 = Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.1)

    model.compile(optimizer=opt, loss=losses.sparse_categorical_crossentropy, metrics=['acc'])
    model.summary()
    return model

model = get_model()
file_path = "srnn_cnn_mitbih.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early

model.fit(X_Train, Y_Train, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

pred_test = model.predict(X_Test)
pred_test = np.argmax(pred_test, axis=-1)

f1 = f1_score(Y_Test, pred_test, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_Test, pred_test)

print("Test accuracy score : %s "% acc)
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 187, 1)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 187, 1)            0
# _________________________________________________________________
# simple_rnn_9 (SimpleRNN)     (None, 64)                4224
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3_mitbih (Dense)       (None, 5)                 325
# =================================================================
# Total params: 12,869
# Trainable params: 12,869
# Non-trainable params: 0
# _________________________________________________________________
# Train on 52794 samples, validate on 5867 samples
# Epoch 1/1000
#  - 123s - loss: 0.6664 - acc: 0.8275 - val_loss: 0.6604 - val_acc: 0.8284
#
# Epoch 00001: val_acc improved from -inf to 0.82836, saving model to srnn_cnn_mitbih.h5
# Epoch 2/1000
#  - 123s - loss: 0.6581 - acc: 0.8287 - val_loss: 0.6607 - val_acc: 0.8284
#
# Epoch 00002: val_acc did not improve from 0.82836
# Epoch 3/1000
#  - 122s - loss: 0.6650 - acc: 0.8283 - val_loss: 0.6665 - val_acc: 0.8284
#
# Epoch 00003: val_acc did not improve from 0.82836
# Epoch 4/1000
#  - 122s - loss: 0.6575 - acc: 0.8287 - val_loss: 0.6653 - val_acc: 0.8284
#
# Epoch 00004: val_acc did not improve from 0.82836
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.010000000149011612.
# Epoch 5/1000
#  - 122s - loss: 0.6541 - acc: 0.8287 - val_loss: 0.6588 - val_acc: 0.8284
#
# Epoch 00005: val_acc did not improve from 0.82836
# Epoch 6/1000
#  - 122s - loss: 0.6540 - acc: 0.8287 - val_loss: 0.6592 - val_acc: 0.8284
#
# Epoch 00006: val_acc did not improve from 0.82836
# Epoch 00006: early stopping
# Test f1 score : 0.18091031449640765
# Test accuracy score : 0.8257363375211989

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(
    X, Y, test_size=0.33, random_state=42)
def get_model():
    nclass = 5
    inp = Input(shape=(187, 1))
    
    img_1 = Dropout(rate=0.25)(inp)
    img_1 = SimpleRNN(64)(img_1)
    img_1 = Dropout(rate=0.25)(img_1)
    dense_1 = Dense(64, activation=activations.relu, name="dense_1")(img_1)
    dense_1 = Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.1)

    model.compile(optimizer=opt, loss=losses.sparse_categorical_crossentropy, metrics=['acc'])
    model.summary()
    return model

model = get_model()
file_path = "srnn_cnn_mitbih.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early

model.fit(X_Train, Y_Train, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

pred_test = model.predict(X_Test)
pred_test = np.argmax(pred_test, axis=-1)

f1 = f1_score(Y_Test, pred_test, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_Test, pred_test)

print("Test accuracy score : %s "% acc)
# Out:
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 187, 1)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 187, 1)            0
# _________________________________________________________________
# simple_rnn_10 (SimpleRNN)    (None, 64)                4224
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3_mitbih (Dense)       (None, 5)                 325
# =================================================================
# Total params: 12,869
# Trainable params: 12,869
# Non-trainable params: 0
# _________________________________________________________________
# Train on 52794 samples, validate on 5867 samples
# Epoch 1/1000
#  - 123s - loss: 0.6971 - acc: 0.8263 - val_loss: 0.6591 - val_acc: 0.8284
#
# Epoch 00001: val_acc improved from -inf to 0.82836, saving model to srnn_cnn_mitbih.h5
# Epoch 2/1000
#  - 122s - loss: 0.6581 - acc: 0.8287 - val_loss: 0.6606 - val_acc: 0.8284
#
# Epoch 00002: val_acc did not improve from 0.82836
# Epoch 3/1000
#  - 123s - loss: 0.6582 - acc: 0.8287 - val_loss: 0.6646 - val_acc: 0.8284
#
# Epoch 00003: val_acc did not improve from 0.82836
# Epoch 4/1000
#  - 122s - loss: 0.6582 - acc: 0.8287 - val_loss: 0.6664 - val_acc: 0.8284
#
# Epoch 00004: val_acc did not improve from 0.82836
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.010000000149011612.
# Epoch 5/1000
#  - 122s - loss: 0.6541 - acc: 0.8287 - val_loss: 0.6595 - val_acc: 0.8284
#
# Epoch 00005: val_acc did not improve from 0.82836
# Epoch 6/1000
#  - 122s - loss: 0.6540 - acc: 0.8287 - val_loss: 0.6596 - val_acc: 0.8284
#
# Epoch 00006: val_acc did not improve from 0.82836
# Epoch 00006: early stopping
# Test f1 score : 0.18091031449640765
# Test accuracy score : 0.8257363375211989

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(
    X, Y, test_size=0.33, random_state=42)
def get_model():
    nclass = 5
    inp = Input(shape=(187, 1))
    
    img_1 = Dropout(rate=0.5)(inp)
    img_1 = SimpleRNN(64)(img_1)
    img_1 = Dropout(rate=0.5)(img_1)
    dense_1 = Dense(64, activation=activations.relu, name="dense_1")(img_1)
    dense_1 = Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.1)

    model.compile(optimizer=opt, loss=losses.sparse_categorical_crossentropy, metrics=['acc'])
    model.summary()
    return model

model = get_model()
file_path = "srnn_cnn_mitbih.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early

model.fit(X_Train, Y_Train, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

pred_test = model.predict(X_Test)
pred_test = np.argmax(pred_test, axis=-1)

f1 = f1_score(Y_Test, pred_test, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_Test, pred_test)

print("Test accuracy score : %s "% acc)
# Out:
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 187, 1)            0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 187, 1)            0
# _________________________________________________________________
# simple_rnn_11 (SimpleRNN)    (None, 64)                4224
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3_mitbih (Dense)       (None, 5)                 325
# =================================================================
# Total params: 12,869
# Trainable params: 12,869
# Non-trainable params: 0
# _________________________________________________________________
# Train on 52794 samples, validate on 5867 samples
# Epoch 1/1000
#  - 124s - loss: 0.6683 - acc: 0.8278 - val_loss: 0.6665 - val_acc: 0.8284
#
# Epoch 00001: val_acc improved from -inf to 0.82836, saving model to srnn_cnn_mitbih.h5
# Epoch 2/1000
#  - 125s - loss: 0.6579 - acc: 0.8287 - val_loss: 0.6662 - val_acc: 0.8284
#
# Epoch 00002: val_acc did not improve from 0.82836
# Epoch 3/1000
#  - 123s - loss: 0.6585 - acc: 0.8287 - val_loss: 0.6606 - val_acc: 0.8284
#
# Epoch 00003: val_acc did not improve from 0.82836
# Epoch 4/1000
#  - 123s - loss: 0.6581 - acc: 0.8287 - val_loss: 0.6599 - val_acc: 0.8284
#
# Epoch 00004: val_acc did not improve from 0.82836
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.010000000149011612.
# Epoch 5/1000
#  - 123s - loss: 0.6540 - acc: 0.8287 - val_loss: 0.6597 - val_acc: 0.8284
#
# Epoch 00005: val_acc did not improve from 0.82836
# Epoch 6/1000
#  - 123s - loss: 0.6539 - acc: 0.8287 - val_loss: 0.6585 - val_acc: 0.8284
#
# Epoch 00006: val_acc did not improve from 0.82836
# Epoch 00006: early stopping
# Test f1 score : 0.18091031449640765
# Test accuracy score : 0.8257363375211989
